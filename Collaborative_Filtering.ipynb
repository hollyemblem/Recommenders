# %% [markdown]
# <a href="https://colab.research.google.com/github/hollyemblem/Recommenders/blob/main/Collaborative_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Collaborative Filtering with MovieTweetings
#
# In this notebook, I explore implementing collaborative filtering with the MovieTweetings dataset. We'll conduct exploratory data analysis, before implementing neighborhood-based collaborative filtering.
#
# Dataset source: https://github.com/sidooms/MovieTweetings/tree/master/recsyschallenge2014

# %% [markdown]
# ![process.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# From Kim Falk's Practical Recommender Systems
